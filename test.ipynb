# %%
# !pip install ollama
# !pip install langchain chromadb gradio 
# !pip install -U langchain-community
# !pip install pymupdf
# Out:
# Requirement already satisfied: ollama in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (0.5.1)
# Requirement already satisfied: httpx>=0.27 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from ollama) (2.11.7)
# Requirement already satisfied: anyio in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from httpx>=0.27->ollama) (4.7.0)
# Requirement already satisfied: certifi in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from httpx>=0.27->ollama) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from httpx>=0.27->ollama) (3.7)
# Requirement already satisfied: h11>=0.16 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from pydantic>=2.9->ollama) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from pydantic>=2.9->ollama) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from pydantic>=2.9->ollama) (0.4.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from anyio->httpx>=0.27->ollama) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from anyio->httpx>=0.27->ollama) (1.3.0)
# Requirement already satisfied: langchain in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (0.3.26)
# Requirement already satisfied: chromadb in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (1.0.15)
# Requirement already satisfied: gradio in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (5.38.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain) (0.3.69)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain) (0.4.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.12.2)
# Requirement already satisfied: packaging>=23.2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2025.7.14)
# Requirement already satisfied: build>=1.0.3 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pybase64>=1.4.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (2.2.6)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (1.35.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (1.35.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (1.35.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (3.11.0)
# Requirement already satisfied: httpx>=0.27.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (4.7.0)
# Requirement already satisfied: brotli>=1.1.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (0.116.1)
# Requirement already satisfied: ffmpy in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (0.6.0)
# Requirement already satisfied: gradio-client==1.11.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (1.11.0)
# Requirement already satisfied: groovy~=0.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (0.1.2)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (0.33.4)
# Requirement already satisfied: jinja2<4.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (3.0.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (2.3.1)
# Requirement already satisfied: pillow<12.0,>=8.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydub in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (0.12.4)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (0.47.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio) (0.13.3)
# Requirement already satisfied: fsspec in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio-client==1.11.0->gradio) (2025.7.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from gradio-client==1.11.0->gradio) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from anyio<5.0,>=3.0->gradio) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: click>=8.0.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: pyproject_hooks in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: filelock in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from huggingface-hub>=0.28.1->gradio) (1.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: google-auth>=1.0.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: coloredlogs in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (6.31.1)
# Requirement already satisfied: sympy in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.35.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.35.0)
# Requirement already satisfied: opentelemetry-proto==1.35.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.35.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.56b0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.56b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: httptools>=0.6.3 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: uvloop>=0.15.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: langchain-community in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-community) (0.3.69)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-community) (0.3.26)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-community) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-community) (3.12.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: langsmith>=0.1.125 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-community) (0.4.7)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.12.2)
# Requirement already satisfied: packaging>=23.2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (2025.7.14)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langsmith>=0.1.125->langchain-community) (3.11.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.7.0)
# Requirement already satisfied: httpcore==1.* in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: pymupdf in /opt/miniconda3/envs/llm_env/lib/python3.10/site-packages (1.26.3)

# %%
# Import necessary packages
import ollama # Ollama API
import gradio as gr # Interface

# Document processing  
from langchain_community.document_loaders import PyMuPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma

# Embedding generation  
from langchain_community.embeddings import OllamaEmbeddings

import re

# %%
# Question au chat bot
response = ollama.chat(
    model="deepseek-r1:1.5b",
    messages=[
        {"role": "user", "content": "Explain Newton's second law of motion"},
    ],
)

print(response["message"]["content"])
# Out:
# <think>
# Okay, so I need to explain Newton's Second Law of Motion. Hmm, let me think about what I remember from my physics class.
#
# Newton's laws are all about how things move and change speed or direction when forces act on them. The first one was about if you have no net force, the object stays at rest or moves at a constant velocity. That makes sense because gravity is pulling everything down, so things fall to Earth.
#
# The second law must be more significant. I think it's F equals mass times acceleration (F=ma). So when there's an unbalanced force acting on something, its acceleration changes. That sounds right. But why does that matter? Well, if you push a box harder, it accelerates faster. If the force is bigger or the mass of the box is smaller, even with the same force, it moves slower.
#
# Wait, but what about when the object isn't moving or not changing direction? Oh, right, if there's no acceleration (because F=0), then a=0. That makes sense because if you stop pushing, the object just stays as it was.
#
# I remember hearing that acceleration is change in velocity over time. So if something goes from one speed to another quickly, like accelerating down a slope, or decelerating while braking. It's also why when you're driving and need to slow down, your brakes apply a force, which changes the car's velocity.
#
# But what about objects moving with constant velocity? If there are no forces acting on them (if F=0), they keep moving at that speed forever, right? So if I push two boxes across a frictionless surface, each box would move at the same speed unless another external force acts on it. That’s why when you're pushing a heavy object versus a light one—it accelerates more because of its mass.
#
# Newton's third law is about forces being equal and opposite when they act on different objects. Like when I push against a wall; I exert a force on the wall, and it pushes back on me. So every action has an equal and opposite reaction. That also ties into why things can be thrown or even rockets launching because of their momentum interactions.
#
# But wait, how does this all connect? Each law explains different aspects of motion. The first is about inertia, the second about acceleration and force, and the third about forces being reciprocal. So together, they form a comprehensive view of how objects move in response to forces.
#
# I should also consider examples. Like when you accelerate a car from rest, the engine applies a force that increases the car's velocity over time. If something is already moving at constant speed, no net force is acting on it—so acceleration remains zero. Forces can change the motion if they cause acceleration or deceleration.
#
# Also, considering different types of forces: gravitational, normal (like when you press against a surface), friction, tension in a string, air resistance, etc. Each applies its own force vector that affects an object's motion accordingly.
#
# I think I've got the gist of it. To summarize, Newton's Second Law explains how acceleration depends on both mass and net force applied. It tells us that forces cause changes in motion and that these changes depend directly on how much force is applied and the inertia (mass) of the object.
# </think>
#
# Newton's Second Law of Motion states that the acceleration of an object is directly proportional to the net force acting on it and inversely proportional to its mass. Mathematically, this is expressed as F = ma, where F is the net force, m is the mass of the object, and a is its acceleration.
#
# - **F**: The net force applied to an object.
# - **m**: The mass of the object, which is a measure of its inertia (resistance to changes in motion).
# - **a**: The acceleration produced by the net force.
#
# **Key Points:**
#
# 1. **Acceleration and Force Relationship**: If a net force acts on an object, it will accelerate. A larger force or more massive objects experience greater acceleration.
#
# 2. **Newton's Third Law**: Forces exist in equal and opposite pairs. For example, when you push against a wall, the wall pushes back with an equal force.
#
# 3. **Constant Velocity**: An object moves at constant velocity when there is no net force acting on it (F = 0), as acceleration would not occur.
#
# 4. **Types of Forces**: Newton's law applies to various forces such as gravity, normal forces, friction, tension, and air resistance, each affecting motion in different ways depending on the direction and magnitude of the force.
#
# 5. **Examples**:
#    - Accelerating a car: The engine provides a net force that increases acceleration.
#    - object at constant speed: No net force, so no acceleration.
#    - Pressing against a wall: Equal forces result in equal pushes back.
#
# In summary, Newton's Second Law explains how the motion of an object is directly influenced by both the mass (inertia) and the net force applied. It provides a fundamental understanding of why objects accelerate when acted upon by external forces.

# %%
def process_pdf(pdf_bytes):
    
    loader = PyMuPDFLoader(pdf_bytes)
    data = loader.load()
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)
    chunks = text_splitter.split_documents(data)

    # Transphorme texte en vecteurs
    embeddings = OllamaEmbeddings(model="bge-m3")
    # Crée la bd vectorielle
    vectorstore = Chroma.from_documents(documents=chunks, embedding=embeddings, persist_directory="./chroma_db")
    # Object pour la recherche
    retriever = vectorstore.as_retriever()
    return text_splitter, vectorstore, retriever

# %%
text_splitter, vectorstore, retriever = process_pdf("Rapport Alternance S6 - Téo Viglietti.pdf")

# %%
# Test de la recherche
print("Recherche dans la base de données vectorielle...")
docs = retriever.get_relevant_documents("Application de suivi des tâches des RDG",k=4)
for doc in docs:
    print(doc.metadata)
    print(doc.page_content)
# Out:
# Recherche dans la base de données vectorielle...
# {'moddate': '2025-06-23T00:36:02-07:00', 'producer': '', 'total_pages': 35, 'format': 'PDF 1.7', 'author': 'admin', 'creationdate': '2025-06-23T00:36:02-07:00', 'creationDate': "D:20250623003602-07'00'", 'subject': '', 'modDate': "D:20250623003602-07'00'", 'keywords': '', 'page': 16, 'source': 'Rapport Alternance S6 - Téo Viglietti.pdf', 'trapped': '', 'creator': 'Microsoft Word', 'file_path': 'Rapport Alternance S6 - Téo Viglietti.pdf', 'title': ''}
# RAPPORT FINAL – ECUE ALTERNANCE S6
#
#
#
#
#
#
# 16 | P A G E
#
# tâches effectuées par les RDG. Ces tâches sont codifiées et transmises via le remplissage d’une feuille de
# service.
#
# Application de suivi des tâches des RDG
# Dans ce cadre, j’ai été chargé par M. Pierre Bolot et M. Stéphane Piozza de modifier le rapport « Tableau
# de bord RDS » ainsi que de créer sa publication dans SAP BO. L’objectif était d’ajouter deux onglets
# {'moddate': '2025-06-23T00:36:02-07:00', 'producer': '', 'author': 'admin', 'trapped': '', 'creator': 'Microsoft Word', 'page': 16, 'subject': '', 'file_path': 'Rapport Alternance S6 - Téo Viglietti.pdf', 'creationDate': "D:20250623003602-07'00'", 'creationdate': '2025-06-23T00:36:02-07:00', 'source': 'Rapport Alternance S6 - Téo Viglietti.pdf', 'keywords': '', 'format': 'PDF 1.7', 'modDate': "D:20250623003602-07'00'", 'title': '', 'total_pages': 35}
# RAPPORT FINAL – ECUE ALTERNANCE S6
#
#
#
#
#
#
# 16 | P A G E
#
# tâches effectuées par les RDG. Ces tâches sont codifiées et transmises via le remplissage d’une feuille de
# service.
#
# Application de suivi des tâches des RDG
# Dans ce cadre, j’ai été chargé par M. Pierre Bolot et M. Stéphane Piozza de modifier le rapport « Tableau
# de bord RDS » ainsi que de créer sa publication dans SAP BO. L’objectif était d’ajouter deux onglets
# {'file_path': 'Rapport Alternance S6 - Téo Viglietti.pdf', 'creationDate': "D:20250623003602-07'00'", 'subject': '', 'total_pages': 35, 'author': 'admin', 'format': 'PDF 1.7', 'title': '', 'trapped': '', 'creator': 'Microsoft Word', 'source': 'Rapport Alternance S6 - Téo Viglietti.pdf', 'producer': '', 'modDate': "D:20250623003602-07'00'", 'creationdate': '2025-06-23T00:36:02-07:00', 'moddate': '2025-06-23T00:36:02-07:00', 'keywords': '', 'page': 16}
# RAPPORT FINAL – ECUE ALTERNANCE S6
#
#
#
#
#
#
# 16 | P A G E
#
# tâches effectuées par les RDG. Ces tâches sont codifiées et transmises via le remplissage d’une feuille de
# service.
#
# Application de suivi des tâches des RDG
# Dans ce cadre, j’ai été chargé par M. Pierre Bolot et M. Stéphane Piozza de modifier le rapport « Tableau
# de bord RDS » ainsi que de créer sa publication dans SAP BO. L’objectif était d’ajouter deux onglets
# {'creator': 'Microsoft Word', 'moddate': '2025-06-23T00:36:02-07:00', 'subject': '', 'title': '', 'creationdate': '2025-06-23T00:36:02-07:00', 'trapped': '', 'keywords': '', 'file_path': 'Rapport Alternance S6 - Téo Viglietti.pdf', 'author': 'admin', 'format': 'PDF 1.7', 'modDate': "D:20250623003602-07'00'", 'total_pages': 35, 'producer': '', 'page': 16, 'source': 'Rapport Alternance S6 - Téo Viglietti.pdf', 'creationDate': "D:20250623003602-07'00'"}
# RAPPORT FINAL – ECUE ALTERNANCE S6
#
#
#
#
#
#
# 16 | P A G E
#
# tâches effectuées par les RDG. Ces tâches sont codifiées et transmises via le remplissage d’une feuille de
# service.
#
# Application de suivi des tâches des RDG
# Dans ce cadre, j’ai été chargé par M. Pierre Bolot et M. Stéphane Piozza de modifier le rapport « Tableau
# de bord RDS » ainsi que de créer sa publication dans SAP BO. L’objectif était d’ajouter deux onglets

# %%
def combine_docs(docs):
    l_docs = []
    for doc in docs:
        if doc.page_content not in l_docs:
            l_docs.append(doc.page_content)
    return "\n\n".join(l_docs)

# %%
combine_docs(docs)
# Out:
# 'RAPPORT FINAL – ECUE ALTERNANCE S6 \n \n \n \n \n   \n \n16 | P A G E  \n \ntâches effectuées par les RDG. Ces tâches sont codifiées et transmises via le remplissage d’une feuille de \nservice. \n \nApplication de suivi des tâches des RDG \nDans ce cadre, j’ai été chargé par M. Pierre Bolot et M. Stéphane Piozza de modifier le rapport « Tableau \nde bord RDS » ainsi que de créer sa publication dans SAP BO. L’objectif était d’ajouter deux onglets'

# %%
def ollama_llm(question, context):
    formatted_prompt = f"Question: {question}\n\nContext: {context}\n\n Répond uniquement en français."
    response = ollama.chat(
        model="gemma3n:e2b",
        messages=[{'role': 'user', 'content': formatted_prompt}]
    )

    response_content = response['message']['content']
    final_answer = re.sub(r'<think>.*?</think>',
                          '',
                          response_content,
                          flags=re.DOTALL).strip()
    return final_answer

# %%
question = "Application de suivi des tâches des RDG"
docs = retriever.get_relevant_documents(question,k=4)
combined_text = combine_docs(docs)
print(combined_text)
ollama_llm(question, combined_text)
# Out:
# RAPPORT FINAL – ECUE ALTERNANCE S6
#
#
#
#
#
#
# 16 | P A G E
#
# tâches effectuées par les RDG. Ces tâches sont codifiées et transmises via le remplissage d’une feuille de
# service.
#
# Application de suivi des tâches des RDG
# Dans ce cadre, j’ai été chargé par M. Pierre Bolot et M. Stéphane Piozza de modifier le rapport « Tableau
# de bord RDS » ainsi que de créer sa publication dans SAP BO. L’objectif était d’ajouter deux onglets
# 'L\'application de suivi des tâches des RDG est un système où les tâches effectuées par les RDG sont codifiées et transmises via un formulaire de service.\n\nL\'objectif de la modification du rapport "Tableau de bord RDS" et de sa publication dans SAP BO, comme vous l\'avez mentionné, était d\'ajouter deux onglets.'

# %%
import gradio as gr

def ask_model(question):
    docs = retriever.get_relevant_documents(question, k=4)
    combined_text = combine_docs(docs)
    response = ollama_llm(question, combined_text)
    return response

# Création de l'interface
interface = gr.Interface(
    fn=ask_model,
    inputs=gr.Textbox(lines=2, label="Pose ta question"),
    outputs=gr.Textbox(label="Réponse du modèle"),
    title="Interface avec Ollama",
    description="Pose une question"
)

# Lancement
interface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
